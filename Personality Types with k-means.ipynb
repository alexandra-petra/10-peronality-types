# %% [markdown]
# ## 10 Peronality types of all people

# %%
# dowloading 1 mln responces to 5 personality tests from kaggle:
# https://www.kaggle.com/datasets/tunguz/big-five-personality-test
# feed the model
# deviding humanity into 10 persnality types by visualizing the datatypes

# %%
from IPython.display import Image
Image("differing-personality-mc.jpg")

# %%
import pandas as pd
df = pd.read_csv("data-final.csv", delimiter = "\t")

df
# Out:
#          EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0         4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1         3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2         2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3         2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4         3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0    3.0  ...
# 1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0    3.0  ...
# 1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0    4.0  ...
# 1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0    4.0  ...
# 1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0    4.0  ...
#
#                     dateload  screenw  screenh  introelapse  testelapse  \
# ...

# %%
columns = df.columns

# %%
for column in columns:
    print(column)
# Out:
# EXT1
# EXT2
# EXT3
# EXT4
# EXT5
# EXT6
# EXT7
# EXT8
# EXT9
# EXT10
# EST1
# EST2
# EST3
# EST4
# EST5
# EST6
# EST7
# EST8
# EST9
# EST10
# AGR1
# AGR2
# AGR3
# AGR4
# AGR5
# AGR6
# AGR7
# AGR8
# AGR9
# AGR10
# CSN1
# CSN2
# CSN3
# CSN4
# CSN5
# CSN6
# CSN7
# CSN8
# CSN9
# CSN10
# OPN1
# OPN2
# OPN3
# OPN4
# OPN5
# OPN6
# OPN7
# OPN8
# OPN9
# OPN10
# EXT1_E
# EXT2_E
# EXT3_E
# EXT4_E
# EXT5_E
# EXT6_E
# EXT7_E
# EXT8_E
# EXT9_E
# EXT10_E
# EST1_E
# EST2_E
# EST3_E
# EST4_E
# EST5_E
# EST6_E
# EST7_E
# EST8_E
# EST9_E
# EST10_E
# AGR1_E
# AGR2_E
# AGR3_E
# AGR4_E
# AGR5_E
# AGR6_E
# AGR7_E
# AGR8_E
# AGR9_E
# AGR10_E
# CSN1_E
# CSN2_E
# CSN3_E
# CSN4_E
# CSN5_E
# CSN6_E
# CSN7_E
# CSN8_E
# CSN9_E
# CSN10_E
# OPN1_E
# OPN2_E
# OPN3_E
# OPN4_E
# OPN5_E
# OPN6_E
# OPN7_E
# OPN8_E
# OPN9_E
# OPN10_E
# dateload
# screenw
# screenh
# introelapse
# testelapse
# endelapse
# IPC
# country
# lat_appx_lots_of_err
# long_appx_lots_of_err

# %% [markdown]
# According to the dataset description on kaggle, dataset contains metadata, such as size of the screen. We not gonna need that info, so we shrink the dataset to the firsta 50 columns

# %% [markdown]
# Data is already in a good shape, so we donät need to work it out

# %%
import numpy as np

# %%
X = df[df.columns[0:50]] # take only 50 columns. set them to "a"

# %%
X
# Out:
#          EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0         4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1         3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2         2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3         2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4         3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0    3.0  ...
# 1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0    3.0  ...
# 1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0    4.0  ...
# 1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0    4.0  ...
# 1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0    4.0  ...
#
#          OPN1  OPN2  OPN3  OPN4  OPN5  OPN6  OPN7  OPN8  OPN9  OPN10
# ...

# %%
pd.set_option("display.max_columns", None) # to see entire dataframe

# %%
X
# Out:
#          EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  EST1  \
# 0         4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0   1.0
# 1         3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0   2.0
# 2         2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0   4.0
# 3         2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0   3.0
# 4         3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0   1.0
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...    ...   ...
# 1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0    3.0   4.0
# 1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0    3.0   4.0
# 1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0    4.0   3.0
# 1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0    4.0   4.0
# 1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0    4.0   4.0
#
# ...

# %%
X = X.fillna(0) # filling missing enties with 0

# %%
from sklearn.cluster import MiniBatchKMeans

# %% [markdown]
# kmeans model parameters:
#
# - number of clusters = number of personality types,
# - batch = batch of data, what is going to be trained at once
# - max_iterations = to feed all 1 mln rows

# %%
kmeans = MiniBatchKMeans(n_clusters = 10, random_state = 0, batch_size = 100, max_iter = 100).fit(X)

# %%
len(kmeans.cluster_centers_)
# Out:
# 10

# %%
one = kmeans.cluster_centers_[0] # personality type 1

# %%
two = kmeans.cluster_centers_[1] # personality type 2

# %%
three = kmeans.cluster_centers_[2] # personality type 3

# %%
four = kmeans.cluster_centers_[3] # personality type 4

# %%
five = kmeans.cluster_centers_[4] # personality type 5

# %%
six = kmeans.cluster_centers_[5] # personality type 6

# %%
seven = kmeans.cluster_centers_[6] # personality type 7

# %%
eight = kmeans.cluster_centers_[7] # personality type 8

# %%
nine = kmeans.cluster_centers_[8] # personality type 9

# %%
ten = kmeans.cluster_centers_[9] # personality type 10

# %%
one # inspecting results for cluster 1
# Picture of personality type 1 contains answers to all the 50 personality questions:
# how the type of personality 1 would answer all the questions
# Out:
# array([1.93983934, 3.62299673, 2.80859288, 3.83687207, 2.45220409,
#        2.9566675 , 1.91850177, 3.95175052, 2.47718339, 4.23629097,
#        2.31209655, 3.96665922, 3.16344346, 3.00845352, 2.27520608,
#        1.88191368, 2.20033393, 1.77677715, 2.29170556, 2.33806187,
#        2.46934778, 3.39960296, 2.23424004, 3.54805885, 2.689652  ,
#        3.32537502, 2.65042136, 3.3468835 , 3.2720508 , 3.27303682,
#        2.9157409 , 3.49625968, 3.72152032, 2.75739847, 1.97141843,
#        3.36907563, 3.26358413, 2.72897467, 2.49556289, 3.35670431,
#        3.77605406, 1.79812787, 3.97993768, 1.80794867, 3.78508605,
#        1.87929742, 4.11344543, 3.30080328, 4.14278953, 3.93677609])

# %% [markdown]
# since we know what are the personality traits the questions relate to, so we can calculate "personality score"

# %% [markdown]
# # Personality scores

# %%
one_scores = {}

one_scores['extroversion_score'] =  one[0] - one[1] + one[2] - one[3] + one[4] - one[5] + one[6] - one[7] + one[8] - one[9]
one_scores['neuroticism_score'] =  one[0] - one[1] + one[2] - one[3] + one[4] + one[5] + one[6] + one[7] + one[8] + one[9]
one_scores['agreeableness_score'] =  -one[0] + one[1] - one[2] + one[3] - one[4] - one[5] + one[6] - one[7] + one[8] + one[9]
one_scores['conscientiousness_score'] =  one[0] - one[1] + one[2] - one[3] + one[4] - one[5] + one[6] - one[7] + one[8] + one[9]
one_scores['openness_score'] =  one[0] - one[1] + one[2] - one[3] + one[4] - one[5] + one[6] + one[7] + one[8] + one[9]

# %%
one_scores # see what personality type 1 is all about
# Out:
# {'extroversion_score': -7.008256313845145,
#  'neuroticism_score': 15.281161668616864,
#  'agreeableness_score': 1.982790581491693,
#  'conscientiousness_score': 1.4643256248110226,
#  'openness_score': 9.367826669997259}

# %%
all_types = {'one': one, 'two': two, 'three': three, 'four': four, 'five': five, 'six': six, 'seven': seven, 'eight': eight, 'nine': nine, 'ten': ten}

all_types_scores = {} 

for name, personality_type in all_types.items():
    personality_trait = {}    
    personality_trait['extraversion_score'] = personality_type[0] - personality_type[1] + personality_type[2] - personality_type[3] + personality_type[4] - personality_type[5] + personality_type[6] - personality_type[7] + personality_type[8] - personality_type[9]
    personality_trait['neuroticism_score'] = personality_type[0] - personality_type[1] + personality_type[2] - personality_type[3] + personality_type[4] + personality_type[5] + personality_type[6] + personality_type[7] + personality_type[8] + personality_type[9]
    personality_trait['agreeableness_score'] = -personality_type[0] + personality_type[1] - personality_type[2] + personality_type[3] - personality_type[4] - personality_type[5] + personality_type[6] - personality_type[7] + personality_type[8] + personality_type[9]
    personality_trait['conscientiousness_score'] = personality_type[0] - personality_type[1] + personality_type[2] - personality_type[3] + personality_type[4] - personality_type[5] + personality_type[6] - personality_type[7] + personality_type[8] + personality_type[9]
    personality_trait['openness_score'] = personality_type[0] - personality_type[1] + personality_type[2] - personality_type[3] + personality_type[4] - personality_type[5] + personality_type[6] + personality_type[7] + personality_type[8] + personality_type[9]

    all_types_scores[name] = personality_trait

# %%
all_types_scores
# Out:
# {'one': {'extraversion_score': -7.008256313845145,
#   'neuroticism_score': 15.281161668616864,
#   'agreeableness_score': 1.982790581491693,
#   'conscientiousness_score': 1.4643256248110226,
#   'openness_score': 9.367826669997259},
#  'two': {'extraversion_score': -10.229991474595797,
#   'neuroticism_score': 13.391061786745253,
#   'agreeableness_score': 3.0909675585934147,
#   'conscientiousness_score': -1.2840604854993192,
#   'openness_score': 6.818423847200863},
#  'three': {'extraversion_score': -4.004688574464987,
#   'neuroticism_score': 16.545062410135674,
#   'agreeableness_score': 1.58223759611572,
#   'conscientiousness_score': 4.319177311467197,
#   'openness_score': 11.899414449144608},
#  'four': {'extraversion_score': -3.034395315597741,
#   'neuroticism_score': 17.494029231407637,
#   'agreeableness_score': 0.20233759048363087,
#   'conscientiousness_score': 4.839111992254154,
#   'openness_score': 12.743326110009697},
# ...

# %% [markdown]
# # Normalization

# %% [markdown]
# magnitude of all scores aren't relative to each other, so we can not see them in one scale. For that let's use normalization with the help of simple equation:

# %% [markdown]
# $$z_i = \frac{xi - min(x)}{max(x) - min(x)}$$

# %%
all_extroversion = []
all_neuroticism =[]
all_agreeableness =[]
all_conscientiousness =[]
all_openness =[]

for personality_type, personality_trait in all_types_scores.items():
    all_extraversion.append(personality_trait['extraversion_score'])
    all_neuroticism.append(personality_trait['neuroticism_score'])
    all_agreeableness.append(personality_trait['agreeableness_score'])
    all_conscientiousness.append(personality_trait['conscientiousness_score'])
    all_openness.append(personality_trait['openness_score'])

# %%
all_extraversion_normalized = (all_extraversion-min(all_extraversion))/(max(all_extraversion)-min(all_extraversion))
all_neuroticism_normalized = (all_neuroticism-min(all_neuroticism))/(max(all_neuroticism)-min(all_neuroticism))
all_agreeableness_normalized = (all_agreeableness-min(all_agreeableness))/(max(all_agreeableness)-min(all_agreeableness))
all_conscientiousness_normalized = (all_conscientiousness-min(all_conscientiousness))/(max(all_conscientiousness)-min(all_conscientiousness))
all_openness_normalized = (all_openness-min(all_openness))/(max(all_openness)-min(all_openness))

# %%
all_extraversion_normalized
# Out:
# array([0.16999693, 0.0185651 , 0.31117419, 0.35678107, 0.95781399,
#        0.67314373, 1.        , 0.        , 0.51842881, 0.60021362])

# %%
counter = 0

normalized_all_types_scores ={}

for personality_type, personality_trait in all_types_scores.items():
    normalized_personality_trait ={}
    normalized_personality_trait['extraversion_score'] = all_extraversion_normalized[counter]
    normalized_personality_trait['neuroticism_score'] = all_neuroticism_normalized[counter]
    normalized_personality_trait['agreeableness_score'] = all_agreeableness_normalized[counter]
    normalized_personality_trait['conscientiousness_score'] = all_conscientiousness_normalized[counter]
    normalized_personality_trait['openness_score'] = all_openness_normalized[counter]
    
    normalized_all_types_scores[personality_type] = normalized_personality_trait
    
    counter+=1

# %%
normalized_all_types_scores
# Out:
# {'one': {'extraversion_score': 0.1699969284178586,
#   'neuroticism_score': 0.6277742622142866,
#   'agreeableness_score': 0.8132588217265576,
#   'conscientiousness_score': 0.18174725704475928,
#   'openness_score': 0.42780056784748316},
#  'two': {'extraversion_score': 0.018565100208695264,
#   'neuroticism_score': 0.5420362302994013,
#   'agreeableness_score': 1.0,
#   'conscientiousness_score': 0.017515415406981892,
#   'openness_score': 0.29658341798875265},
#  'three': {'extraversion_score': 0.3111741919823864,
#   'neuroticism_score': 0.6851068736561128,
#   'agreeableness_score': 0.7457608155455572,
#   'conscientiousness_score': 0.35234102781931614,
#   'openness_score': 0.5581007816962062},
#  'four': {'extraversion_score': 0.3567810698782899,
#   'neuroticism_score': 0.7281535657324153,
#   'agreeableness_score': 0.5132310316971305,
#   'conscientiousness_score': 0.3834101086288353,
#   'openness_score': 0.6015367118211288},
# ...

# %% [markdown]
# # Visualization of 10 peronality types

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15,5))

y = normalized_all_types_scores['one'].values()
my_labels = list(normalized_all_types_scores['one'].keys())
myexplode = [0.05, 0.05, 0.05, 0.05, 0.05]
my_colors = ['pink', 'silver', 'lightsteelblue', 'navajowhite', 'cadetblue'] 
plt.pie(y, labels = my_labels, explode = myexplode, colors = my_colors)

plt.show()
# Out:
# /var/folders/t7/l_bg6rl90297v4jg3wgrrjgw0000gn/T/ipykernel_24443/2824394249.py:16: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
plt.figure(figsize=(5,5))

y = normalized_all_types_scores['two'].values()
my_labels = list(normalized_all_types_scores['two'].keys())
myexplode = [0.05, 0.05, 0.05, 0.05, 0.05]
my_colors = ['pink', 'silver', 'lightsteelblue', 'navajowhite', 'cadetblue'] 
plt.pie(y, labels = my_labels, explode = myexplode, colors = my_colors)

plt.show()
# Out:
# /var/folders/t7/l_bg6rl90297v4jg3wgrrjgw0000gn/T/ipykernel_24443/682119810.py:9: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
plt.figure(figsize=(5,5))

y = normalized_all_types_scores['three'].values()
my_labels = list(normalized_all_types_scores['three'].keys())
myexplode = [0.05, 0.05, 0.05, 0.05, 0.05]
my_colors = ['pink', 'silver', 'lightsteelblue', 'navajowhite', 'cadetblue'] 
plt.pie(y, labels = my_labels, explode = myexplode, colors = my_colors)

plt.show()
# Out:
# /var/folders/t7/l_bg6rl90297v4jg3wgrrjgw0000gn/T/ipykernel_24443/1085078820.py:9: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
plt.figure(figsize=(5,5))

y = normalized_all_types_scores['four'].values()
my_labels = list(normalized_all_types_scores['four'].keys())
myexplode = [0.05, 0.05, 0.05, 0.05, 0.05]
my_colors = ['pink', 'silver', 'lightsteelblue', 'navajowhite', 'cadetblue'] 
plt.pie(y, labels = my_labels, explode = myexplode, colors = my_colors)

plt.show()
# Out:
# /var/folders/t7/l_bg6rl90297v4jg3wgrrjgw0000gn/T/ipykernel_24443/3922787126.py:9: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
plt.figure(figsize=(5,5))

y = normalized_all_types_scores['five'].values()
my_labels = list(normalized_all_types_scores['five'].keys())
myexplode = [0.05, 0.05, 0.05, 0.05, 0.05]
my_colors = ['pink', 'silver', 'lightsteelblue', 'navajowhite', 'cadetblue'] 
plt.pie(y, labels = my_labels, explode = myexplode, colors = my_colors)

plt.show()
# Out:
# /var/folders/t7/l_bg6rl90297v4jg3wgrrjgw0000gn/T/ipykernel_24443/3150918220.py:9: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
plt.figure(figsize=(5,5))

y = normalized_all_types_scores['six'].values()
my_labels = list(normalized_all_types_scores['six'].keys())
myexplode = [0.05, 0.05, 0.05, 0.05, 0.05]
my_colors = ['pink', 'silver', 'lightsteelblue', 'navajowhite', 'cadetblue'] 
plt.pie(y, labels = my_labels, explode = myexplode, colors = my_colors)

plt.show()
# Out:
# /var/folders/t7/l_bg6rl90297v4jg3wgrrjgw0000gn/T/ipykernel_24443/2469055096.py:9: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
plt.figure(figsize=(5,5))

y = normalized_all_types_scores['seven'].values()
my_labels = list(normalized_all_types_scores['seven'].keys())
myexplode = [0.05, 0.05, 0.05, 0.05, 0.05]
my_colors = ['pink', 'silver', 'lightsteelblue', 'navajowhite', 'cadetblue'] 
plt.pie(y, labels = my_labels, explode = myexplode, colors = my_colors)

plt.show()
# Out:
# /var/folders/t7/l_bg6rl90297v4jg3wgrrjgw0000gn/T/ipykernel_24443/2247167805.py:9: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
plt.figure(figsize=(5,5))

y = normalized_all_types_scores['eight'].values()
my_labels = list(normalized_all_types_scores['eight'].keys())
myexplode = [0.05, 0.05, 0.05, 0.05, 0.05]
my_colors = ['pink', 'silver', 'lightsteelblue', 'navajowhite', 'cadetblue'] 
plt.pie(y, labels = my_labels, explode = myexplode, colors = my_colors)

plt.show()
# Out:
# /var/folders/t7/l_bg6rl90297v4jg3wgrrjgw0000gn/T/ipykernel_24443/460663265.py:9: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
plt.figure(figsize=(5,5))

y = normalized_all_types_scores['nine'].values()
my_labels = list(normalized_all_types_scores['nine'].keys())
myexplode = [0.05, 0.05, 0.05, 0.05, 0.05]
my_colors = ['pink', 'silver', 'lightsteelblue', 'navajowhite', 'cadetblue'] 
plt.pie(y, labels = my_labels, explode = myexplode, colors = my_colors)

plt.show()
# Out:
# /var/folders/t7/l_bg6rl90297v4jg3wgrrjgw0000gn/T/ipykernel_24443/3255045302.py:9: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
plt.figure(figsize=(5, 5))

y = normalized_all_types_scores['ten'].values()
my_labels = list(normalized_all_types_scores['ten'].keys())
myexplode = [0.05, 0.05, 0.05, 0.05, 0.05]
my_colors = ['pink', 'silver', 'lightsteelblue', 'navajowhite', 'cadetblue'] 
plt.pie(y, labels = my_labels, explode = myexplode, colors = my_colors)

plt.show()
# Out:
# /var/folders/t7/l_bg6rl90297v4jg3wgrrjgw0000gn/T/ipykernel_24443/2857173602.py:9: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# # Outcome

# %% [markdown]
# Using unsupervised algorithm of k-means we devided people into 10 peronality types according to the Big Five personality traits: extraversion, neuroticism, agreeableness, conscientiousness, openness. Quite remarkable is type # 7, which has 0 agreeableness, and shares all the rest 4 traits in the same proportion. 1/10 of people is like that 𝌂𝌄🤖🧬📉
